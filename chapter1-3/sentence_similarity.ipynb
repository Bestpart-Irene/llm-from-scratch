# %%
from nltk.metrics.aline import similarity_matrix
# !pip install sentence_transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 61.5 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.1/566.1 kB 33.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 39.7 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 MB 74.6 MB/s  0:00:00 eta 0:00:01
# ...
#   Attempting uninstall: huggingface-hub━━━━━━━━━ 0/5 [torch]
#     Found existing installation: huggingface_hub 1.2.30/5 [torch]
#     Uninstalling huggingface_hub-1.2.3:━━━━━ 0/5 [torch]
#       Successfully uninstalled huggingface_hub-1.2.32m0/5 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [sentence_transformers]ence_transformers]
# ...

# %%
#download model bge
from modelscope import snapshot_download
model_dir = snapshot_download('BAAI/bge-base-zh', cache_dir="./")
# Out:
# ...
# 2026-01-01 11:40:58,199 - modelscope - INFO - Got 13 files, start to download ...
# Processing 13 items:   0%|          | 0.00/13.0 [00:00<?, ?it/s]
# ...
# 2026-01-01 11:41:25,191 - modelscope - INFO - Download model 'BAAI/bge-base-zh' successfully.

# %%
#import model bge
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("BAAI/bge-base-zh")

# %%
#sentences embedding
sentences_1 = ["Where are you now? Atlantis Under the sea Under the sea",
               "The monster's running wild inside of me"]
sentences_2 = ["Follow everywhere I go Top over the mountains or valley low", "Everything you wantin' gonna be the magic story you've been told"]

embeddings_1 = model.encode(sentences_1)
embeddings_2 = model.encode(sentences_2)

# %%
embeddings_1
# Out:
# array([[ 0.01270839,  0.02092049,  0.03678461, ..., -0.05618246,
#         -0.00422555, -0.03663189],
#        [ 0.01161791,  0.04997335,  0.03297903, ..., -0.02223131,
#         -0.03885555, -0.01573565]], shape=(2, 768), dtype=float32)

# %%
#similarity of sentences 1 and 2
similarity = embeddings_1@embeddings_2.T
similarity
# Out:
# array([[0.7990189 , 0.77160347],
#        [0.7769277 , 0.746073  ]], dtype=float32)

# %%
embeddings_1[1]@embeddings_2[0].T
# Out:
# np.float32(0.77692735)
